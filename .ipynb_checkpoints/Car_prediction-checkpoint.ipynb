# %%
# !pip install neat-python pygame

import math
import random
import sys
import os
import neat
import pygame
# Out:
# Requirement already satisfied: neat-python in c:\users\lucas\anaconda3\lib\site-packages (0.92)
# Requirement already satisfied: pygame in c:\users\lucas\anaconda3\lib\site-packages (2.6.0)
# pygame 2.6.0 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
WIDTH = 1920
HEIGHT = 1080
CAR_SIZE_X = 30    
CAR_SIZE_Y = 30
BORDER_COLOR = (255, 255, 255, 255) # color for collisions
current_generation = 0 # count generation

# %%
class Car:
    def __init__(self):
        # Charging the car.png
        self.sprite = pygame.image.load('car.png').convert()
        self.sprite = pygame.transform.scale(self.sprite, (CAR_SIZE_X, CAR_SIZE_Y))
        self.rotated_sprite = self.sprite 

        self.position = [830, 920] # Starting position
        self.angle = 0
        self.speed = 0
        self.speed_set = False # Indicate initial speed
        self.center = [self.position[0] + CAR_SIZE_X / 2, self.position[1] + CAR_SIZE_Y / 2] # Calculate center
        self.radars = [] # radar list
        self.drawing_radars = [] # radars to draw
        self.alive = True # Indicate car state
        self.distance = 0 # Distance driven
        self.time = 0 # time passed
        
    #################### Draw car and radars ###########################

    def draw(self, screen):
        screen.blit(self.rotated_sprite, self.position) # Draw Sprite
        self.draw_radar(screen) #OPTIONAL FOR SENSORS


    def draw_radar(self, screen):
        # Optionally Draw All Sensors / Radars
        for radar in self.radars:
            position = radar[0]
            distance = radar[1]
            # Change color based on distance
            if distance < 50:  # Example threshold for changing color
                color = (255, 0, 0)  # Red
            else:
                color = (0, 255, 0)  # Green
            pygame.draw.line(screen, color, self.center, position, 1)
            pygame.draw.circle(screen, color, position, 5)

    #################### Check if car hit the border ################################      

    def check_collision(self, game_map):
        self.alive = True
        for point in self.corners:
            # If Any Corner Touches Border Color -> Crash
            # Assumes Rectangle
            if game_map.get_at((int(point[0]), int(point[1]))) == BORDER_COLOR:
                self.alive = False
                break

    #################### Calcul distance betwen a position and a border ################################       

    def check_radar(self, degree, game_map):
        length = 0
        x = int(self.center[0] + math.cos(math.radians(360 - (self.angle + degree))) * length)
        y = int(self.center[1] + math.sin(math.radians(360 - (self.angle + degree))) * length)

        # While We Don't Hit BORDER_COLOR AND length < 300 (just a max) -> go further and further
        while not game_map.get_at((x, y)) == BORDER_COLOR and length < 300:
            length = length + 1
            x = int(self.center[0] + math.cos(math.radians(360 - (self.angle + degree))) * length)
            y = int(self.center[1] + math.sin(math.radians(360 - (self.angle + degree))) * length)

        # Calculate Distance To Border And Append To Radars List
        dist = int(math.sqrt(math.pow(x - self.center[0], 2) + math.pow(y - self.center[1], 2)))
        self.radars.append([(x, y), dist])


    ################## Update car position , angle , speed , check radar distance and collisions ############

    def update(self, game_map):
        # Set The Speed To 20 For The First Time
        # Only When Having 4 Output Nodes With Speed Up and Down
        if not self.speed_set:
            self.speed = 20
            self.speed_set = True

        # Get Rotated Sprite And Move Into The Right X-Direction
        # Don't Let The Car Go Closer Than 20px To The Edge
        self.rotated_sprite = self.rotate_center(self.sprite, self.angle)
        self.position[0] += math.cos(math.radians(360 - self.angle)) * self.speed
        self.position[0] = max(self.position[0], 20)
        self.position[0] = min(self.position[0], WIDTH - 120)

        # Increase Distance and Time
        self.distance += self.speed
        self.time += 1

        # Same For Y-Position
        self.position[1] += math.sin(math.radians(360 - self.angle)) * self.speed
        self.position[1] = max(self.position[1], 20)
        self.position[1] = min(self.position[1], WIDTH - 120)

        # Calculate New Center
        self.center = [int(self.position[0]) + CAR_SIZE_X / 2, int(self.position[1]) + CAR_SIZE_Y / 2]

        # Calculate Four Corners
        # Length Is Half The Side
        length = 0.5 * CAR_SIZE_X
        left_top = [self.center[0] + math.cos(math.radians(360 - (self.angle + 30))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 30))) * length]
        right_top = [self.center[0] + math.cos(math.radians(360 - (self.angle + 150))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 150))) * length]
        left_bottom = [self.center[0] + math.cos(math.radians(360 - (self.angle + 210))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 210))) * length]
        right_bottom = [self.center[0] + math.cos(math.radians(360 - (self.angle + 330))) * length, self.center[1] + math.sin(math.radians(360 - (self.angle + 330))) * length]
        self.corners = [left_top, right_top, left_bottom, right_bottom]

        # Check Collisions And Clear Radars
        self.check_collision(game_map)
        self.radars.clear()

        # From -90 To 120 With Step-Size 45 Check Radar
        for d in range(-90, 120, 45):
            self.check_radar(d, game_map)


    ################# Give radar distance ############################    

    def get_data(self):
        # Get Distances To Border
        radars = self.radars
        return_values = [0, 0, 0, 0, 0]
        for i, radar in enumerate(radars):
            return_values[i] = int(radar[1] / 30)

        return return_values

    ################### Check the state of the car (True/False) ####################

    def is_alive(self):
        # Basic Alive Function
        return self.alive

    ################ Calculate the reward on the distance travaled ##############################

    def get_reward(self):
        # Calculate Reward (Maybe Change?)
        # return self.distance / 50.0
        return self.distance / (CAR_SIZE_X / 2)


    ############## Rotate the car ################################

    def rotate_center(self, image, angle):
        # Rotate The Rectangle
        rectangle = image.get_rect()
        rotated_image = pygame.transform.rotate(image, angle)
        rotated_rectangle = rectangle.copy()
        rotated_rectangle.center = rotated_image.get_rect().center
        rotated_image = rotated_image.subsurface(rotated_rectangle).copy()
        return rotated_image

# %%
def run_simulation(genomes, config):
    nets = []
    cars = []

    pygame.init()
    screen = pygame.display.set_mode((WIDTH, HEIGHT), pygame.FULLSCREEN)

    for i, g in genomes:
        net = neat.nn.FeedForwardNetwork.create(g, config)
        nets.append(net)
        g.fitness = 0
        cars.append(Car())

    clock = pygame.time.Clock()
    generation_font = pygame.font.SysFont("Arial", 30)
    alive_font = pygame.font.SysFont("Arial", 20)
    game_map = pygame.image.load('map5.png').convert()

    global current_generation
    current_generation += 1

    counter = 0

    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                sys.exit(0)

        for i, car in enumerate(cars):
            output = nets[i].activate(car.get_data())
            choice = output.index(max(output))
            if choice == 0:
                car.angle += 10 # Left
            elif choice == 1:
                car.angle -= 10 # Right
            elif choice == 2:
                if(car.speed - 2 >= 12):
                    car.speed -= 2 # Slow down
            else:
                car.speed += 2 # Speed up

        still_alive = 0
        for i, car in enumerate(cars):
            if car.is_alive():
                still_alive += 1
                car.update(game_map)
                genomes[i][1].fitness += car.get_reward()

        if still_alive == 0:
            break

        counter += 1
        if counter == 30 * 40: # Stop after about 20 seconds
            break

        screen.blit(game_map, (0, 0))
        for car in cars:
            if car.is_alive():
                car.draw(screen)

        text = generation_font.render("Generation: " + str(current_generation), True, (0,0,0))
        text_rect = text.get_rect()
        text_rect.center = (900, 450)
        screen.blit(text, text_rect)

        text = alive_font.render("Still Alive: " + str(still_alive), True, (0, 0, 0))
        text_rect = text.get_rect()
        text_rect.center = (900, 490)
        screen.blit(text, text_rect)

        pygame.display.flip()
        clock.tick(60)

# %%
if __name__ == "__main__":
    config_path = "./config.txt"
    config = neat.config.Config(neat.DefaultGenome,
                                neat.DefaultReproduction,
                                neat.DefaultSpeciesSet,
                                neat.DefaultStagnation,
                                config_path)

    population = neat.Population(config)
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)
    
    population.run(run_simulation, 1000)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 16.79111 stdev: 7.88262
# Best fitness: 48.00000 - size: (4, 20) - species 1 - id 18
# Average adjusted fitness: 0.220
# Mean genetic distance 1.306, standard deviation 0.249
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    30     48.0    0.220     0
# Total extinctions: 0
# Generation time: 0.572 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 25.22667 stdev: 13.22702
# Best fitness: 48.00000 - size: (4, 20) - species 1 - id 18
# Average adjusted fitness: 0.431
# Mean genetic distance 1.094, standard deviation 0.275
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    30     48.0    0.431     1
# Total extinctions: 0
# Generation time: 0.326 sec (0.449 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 30.48000 stdev: 13.91605
# Best fitness: 48.00000 - size: (4, 20) - species 1 - id 18
# Average adjusted fitness: 0.556
# Mean genetic distance 0.941, standard deviation 0.231
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    30     48.0    0.556     2
# Total extinctions: 0
# Generation time: 0.330 sec (0.409 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 34.88889 stdev: 12.73820
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 91
# Average adjusted fitness: 0.597
# Mean genetic distance 0.961, standard deviation 0.349
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    30     48.5    0.597     0
# Total extinctions: 0
# Generation time: 0.325 sec (0.388 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 32.77778 stdev: 14.88146
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 91
# Average adjusted fitness: 0.606
# Mean genetic distance 1.086, standard deviation 0.312
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    30     48.5    0.606     1
# Total extinctions: 0
# Generation time: 0.327 sec (0.376 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 38.12000 stdev: 13.36731
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 91
# Average adjusted fitness: 0.740
# Mean genetic distance 1.184, standard deviation 0.217
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    30     48.5    0.740     2
# Total extinctions: 0
# Generation time: 0.324 sec (0.367 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 35.21778 stdev: 14.66561
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 91
# Average adjusted fitness: 0.627
# Mean genetic distance 1.053, standard deviation 0.231
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    30     48.5    0.627     3
# Total extinctions: 0
# Generation time: 0.322 sec (0.361 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 36.02667 stdev: 14.65435
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 173
# Average adjusted fitness: 0.642
# Mean genetic distance 1.091, standard deviation 0.241
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    30     48.5    0.642     4
# Total extinctions: 0
# Generation time: 0.326 sec (0.357 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 36.34667 stdev: 14.85909
# Best fitness: 48.53333 - size: (4, 16) - species 1 - id 173
# Average adjusted fitness: 0.695
# Mean genetic distance 0.984, standard deviation 0.264
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    30     48.5    0.695     5
# Total extinctions: 0
# Generation time: 0.338 sec (0.355 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 39.87556 stdev: 12.36190
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.744
# Mean genetic distance 1.157, standard deviation 0.274
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    30     48.5    0.744     6
# Total extinctions: 0
# Generation time: 0.326 sec (0.352 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 36.76000 stdev: 14.06053
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.707
# Mean genetic distance 1.178, standard deviation 0.374
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    30     48.5    0.707     7
# Total extinctions: 0
# Generation time: 0.352 sec (0.330 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 35.24000 stdev: 13.62939
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.617
# Mean genetic distance 1.102, standard deviation 0.378
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    30     48.5    0.617     8
# Total extinctions: 0
# Generation time: 0.335 sec (0.331 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 33.77333 stdev: 14.27689
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.574
# Mean genetic distance 1.065, standard deviation 0.391
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    30     48.5    0.574     9
# Total extinctions: 0
# Generation time: 0.328 sec (0.330 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 32.01333 stdev: 14.08017
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.527
# Mean genetic distance 1.062, standard deviation 0.358
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    30     48.5    0.527    10
# Total extinctions: 0
# Generation time: 0.331 sec (0.331 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 29.89778 stdev: 15.18723
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.534
# Mean genetic distance 0.984, standard deviation 0.301
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    30     48.5    0.534    11
# Total extinctions: 0
# Generation time: 0.334 sec (0.332 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 34.15111 stdev: 14.46851
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.579
# Mean genetic distance 1.261, standard deviation 0.262
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    30     48.5    0.579    12
# Total extinctions: 0
# Generation time: 0.327 sec (0.332 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 37.73778 stdev: 14.12283
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.689
# Mean genetic distance 1.098, standard deviation 0.335
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    30     48.5    0.689    13
# Total extinctions: 0
# Generation time: 0.326 sec (0.332 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 35.62667 stdev: 14.93787
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.677
# Mean genetic distance 1.032, standard deviation 0.289
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    30     48.5    0.677    14
# Total extinctions: 0
# Generation time: 0.330 sec (0.333 average)
#
#  ****** Running generation 18 ******
# Population's average fitness: 38.87111 stdev: 13.32905
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.758
# Mean genetic distance 1.140, standard deviation 0.281
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    30     48.5    0.758    15
# Total extinctions: 0
# Generation time: 0.326 sec (0.332 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 30.92444 stdev: 13.81215
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.480
# Mean genetic distance 1.181, standard deviation 0.293
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    30     48.5    0.480    16
# Total extinctions: 0
# Generation time: 0.324 sec (0.331 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 27.23556 stdev: 14.45516
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.468
# Mean genetic distance 1.080, standard deviation 0.334
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    30     48.5    0.468    17
# Total extinctions: 0
# Generation time: 0.330 sec (0.329 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 40.00444 stdev: 12.32159
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.748
# Mean genetic distance 1.229, standard deviation 0.323
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    30     48.5    0.748    18
# Total extinctions: 0
# Generation time: 0.327 sec (0.328 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 31.37778 stdev: 14.85963
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.505
# Mean genetic distance 1.129, standard deviation 0.332
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    30     48.5    0.505    19
# Total extinctions: 0
# Generation time: 0.324 sec (0.328 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 32.56444 stdev: 14.21468
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.539
# Mean genetic distance 1.215, standard deviation 0.328
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    30     48.5    0.539    20
# Total extinctions: 0
# Generation time: 0.332 sec (0.328 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 37.59111 stdev: 13.24508
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.726
# Mean genetic distance 1.152, standard deviation 0.276
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    30     48.5    0.726    21
# Total extinctions: 0
# Generation time: 0.326 sec (0.327 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 32.84444 stdev: 14.45825
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.547
# Mean genetic distance 1.025, standard deviation 0.279
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    30     48.5    0.547    22
# Total extinctions: 0
# Generation time: 0.326 sec (0.327 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 39.05333 stdev: 12.43481
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.720
# Mean genetic distance 1.034, standard deviation 0.344
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    30     48.5    0.720    23
# Total extinctions: 0
# Generation time: 0.345 sec (0.329 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 36.57333 stdev: 13.66226
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.647
# Mean genetic distance 1.031, standard deviation 0.288
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    30     48.5    0.647    24
# Total extinctions: 0
# Generation time: 0.331 sec (0.329 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 36.02222 stdev: 14.06634
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.631
# Mean genetic distance 1.098, standard deviation 0.263
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    30     48.5    0.631    25
# Total extinctions: 0
# Generation time: 0.329 sec (0.330 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 33.55111 stdev: 14.22705
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.568
# Mean genetic distance 1.085, standard deviation 0.360
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    30     48.5    0.568    26
# Total extinctions: 0
# Generation time: 0.338 sec (0.331 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 37.87556 stdev: 13.60274
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.695
# Mean genetic distance 1.131, standard deviation 0.294
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    30     48.5    0.695    27
# Total extinctions: 0
# Generation time: 0.325 sec (0.330 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 36.48444 stdev: 14.11535
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.648
# Mean genetic distance 1.120, standard deviation 0.341
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    30     48.5    0.648    28
# Total extinctions: 0
# Generation time: 0.330 sec (0.331 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 39.96889 stdev: 13.21771
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.747
# Mean genetic distance 1.127, standard deviation 0.340
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    30     48.5    0.747    29
# Total extinctions: 0
# Generation time: 0.332 sec (0.332 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 32.72444 stdev: 14.26478
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.544
# Mean genetic distance 1.145, standard deviation 0.331
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    30     48.5    0.544    30
# Total extinctions: 0
# Generation time: 0.330 sec (0.331 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 37.61333 stdev: 12.99729
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.685
# Mean genetic distance 1.152, standard deviation 0.345
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    30     48.5    0.685    31
# Total extinctions: 0
# Generation time: 0.322 sec (0.331 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 34.59111 stdev: 14.71244
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.588
# Mean genetic distance 1.125, standard deviation 0.303
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    30     48.5    0.588    32
# Total extinctions: 0
# Generation time: 0.334 sec (0.332 average)
#
#  ****** Running generation 36 ******
# Population's average fitness: 36.61778 stdev: 13.82204
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.648
# Mean genetic distance 1.033, standard deviation 0.293
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    30     48.5    0.648    33
# Total extinctions: 0
# Generation time: 0.330 sec (0.330 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 35.00000 stdev: 13.99182
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.610
# Mean genetic distance 1.047, standard deviation 0.406
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    30     48.5    0.610    34
# Total extinctions: 0
# Generation time: 0.324 sec (0.329 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 35.40889 stdev: 15.36691
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.627
# Mean genetic distance 0.924, standard deviation 0.353
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    30     48.5    0.627    35
# Total extinctions: 0
# Generation time: 0.324 sec (0.329 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 39.53778 stdev: 13.99389
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.741
# Mean genetic distance 1.082, standard deviation 0.353
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    30     48.5    0.741    36
# Total extinctions: 0
# Generation time: 0.325 sec (0.328 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 38.19556 stdev: 13.82728
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.702
# Mean genetic distance 1.007, standard deviation 0.309
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    30     48.5    0.702    37
# Total extinctions: 0
# Generation time: 0.323 sec (0.327 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 36.48444 stdev: 13.88821
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.652
# Mean genetic distance 1.118, standard deviation 0.379
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    30     48.5    0.652    38
# Total extinctions: 0
# Generation time: 0.327 sec (0.327 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 33.23556 stdev: 14.43576
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.548
# Mean genetic distance 1.076, standard deviation 0.442
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    30     48.5    0.548    39
# Total extinctions: 0
# Generation time: 0.325 sec (0.326 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 37.57333 stdev: 12.38773
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.678
# Mean genetic distance 1.042, standard deviation 0.335
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    30     48.5    0.678    40
# Total extinctions: 0
# Generation time: 0.324 sec (0.326 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 39.24444 stdev: 12.20838
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.726
# Mean genetic distance 1.000, standard deviation 0.407
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    30     48.5    0.726    41
# Total extinctions: 0
# Generation time: 0.324 sec (0.326 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 33.77778 stdev: 14.67137
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.564
# Mean genetic distance 1.264, standard deviation 0.471
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    30     48.5    0.564    42
# Total extinctions: 0
# Generation time: 0.336 sec (0.326 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 38.72444 stdev: 13.33741
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.720
# Mean genetic distance 1.327, standard deviation 0.527
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    28     48.5    0.720    43
#      2    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.325 sec (0.326 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 39.87556 stdev: 13.30494
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.676
# Mean genetic distance 1.552, standard deviation 0.600
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    21     48.5    0.762    44
#      2    1     9     48.5    0.590     0
# Total extinctions: 0
# Generation time: 0.334 sec (0.327 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 36.69333 stdev: 13.43501
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.632
# Mean genetic distance 1.488, standard deviation 0.460
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    18     48.5    0.685    45
#      2    2    12     48.5    0.579     1
# Total extinctions: 0
# Generation time: 0.333 sec (0.327 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 38.78222 stdev: 12.94395
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.723
# Mean genetic distance 1.240, standard deviation 0.463
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49    17     48.5    0.700    46
#      2    3    13     48.5    0.747     2
# Total extinctions: 0
# Generation time: 0.326 sec (0.328 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 36.33333 stdev: 13.38274
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.650
# Mean genetic distance 1.261, standard deviation 0.451
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    16     48.5    0.633    47
#      2    4    14     48.5    0.668     3
# Total extinctions: 0
# Generation time: 0.323 sec (0.328 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 37.58222 stdev: 14.20805
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.691
# Mean genetic distance 1.277, standard deviation 0.476
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    16     48.5    0.628    48
#      2    5    14     48.5    0.753     4
# Total extinctions: 0
# Generation time: 0.330 sec (0.328 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 34.39556 stdev: 14.42301
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.644
# Mean genetic distance 1.300, standard deviation 0.532
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    15     48.5    0.680    49
#      2    6    15     48.5    0.608     5
# Total extinctions: 0
# Generation time: 0.326 sec (0.328 average)
#
#  ****** Running generation 53 ******
# Population's average fitness: 37.06667 stdev: 13.40585
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.679
# Mean genetic distance 1.252, standard deviation 0.538
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    14     48.5    0.652    50
#      2    7    16     48.5    0.706     6
# Total extinctions: 0
# Generation time: 0.327 sec (0.329 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 34.81333 stdev: 13.99362
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.615
# Mean genetic distance 1.294, standard deviation 0.517
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    16     48.5    0.778    51
#      2    8    14     48.5    0.452     7
# Total extinctions: 0
# Generation time: 0.332 sec (0.329 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 38.34667 stdev: 13.44996
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.698
# Mean genetic distance 1.257, standard deviation 0.520
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    18     48.5    0.770    52
#      2    9    12     48.5    0.626     8
# Total extinctions: 0
# Generation time: 0.330 sec (0.329 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 38.58222 stdev: 13.67688
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.719
# Mean genetic distance 1.297, standard deviation 0.484
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    16     48.5    0.690    53
#      2   10    14     48.5    0.748     9
# Total extinctions: 0
# Generation time: 0.331 sec (0.329 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 35.82667 stdev: 14.77612
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.682
# Mean genetic distance 1.324, standard deviation 0.470
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    15     48.5    0.687    54
#      2   11    15     48.5    0.677    10
# Total extinctions: 0
# Generation time: 0.330 sec (0.329 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 39.79111 stdev: 12.52031
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.742
# Mean genetic distance 1.259, standard deviation 0.554
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    16     48.5    0.798    55
#      2   12    14     48.5    0.685    11
# Total extinctions: 0
# Generation time: 0.332 sec (0.329 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 33.71111 stdev: 14.25545
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.573
# Mean genetic distance 1.254, standard deviation 0.548
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    15     48.5    0.596    56
#      2   13    15     48.5    0.549    12
# Total extinctions: 0
# Generation time: 0.337 sec (0.330 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 37.52444 stdev: 12.85418
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.682
# Mean genetic distance 1.285, standard deviation 0.492
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    17     48.5    0.780    57
#      2   14    13     48.5    0.585    13
# Total extinctions: 0
# Generation time: 0.337 sec (0.331 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 33.64000 stdev: 15.21041
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.555
# Mean genetic distance 1.273, standard deviation 0.517
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    17     48.5    0.671    58
#      2   15    13     48.5    0.439    14
# Total extinctions: 0
# Generation time: 0.330 sec (0.331 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 35.75111 stdev: 15.34653
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.685
# Mean genetic distance 1.378, standard deviation 0.528
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62    16     48.5    0.654    59
#      2   16    14     48.5    0.715    15
# Total extinctions: 0
# Generation time: 0.323 sec (0.331 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 33.23111 stdev: 14.92630
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.565
# Mean genetic distance 1.330, standard deviation 0.596
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63    15     48.5    0.541    60
#      2   17    15     48.5    0.589    16
# Total extinctions: 0
# Generation time: 0.342 sec (0.332 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 38.64000 stdev: 13.37307
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.719
# Mean genetic distance 1.285, standard deviation 0.638
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    14     48.5    0.680    61
#      2   18    16     48.5    0.758    17
# Total extinctions: 0
# Generation time: 0.331 sec (0.332 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 35.45333 stdev: 14.29059
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.632
# Mean genetic distance 1.318, standard deviation 0.605
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65    15     48.5    0.681    62
#      2   19    15     48.5    0.582    18
# Total extinctions: 0
# Generation time: 0.323 sec (0.332 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 40.59556 stdev: 11.97408
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.771
# Mean genetic distance 1.371, standard deviation 0.589
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66    14     48.5    0.641    63
#      2   20    16     48.5    0.901    19
# Total extinctions: 0
# Generation time: 0.330 sec (0.331 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 37.20444 stdev: 15.17122
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.717
# Mean genetic distance 1.291, standard deviation 0.580
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    15     48.5    0.716    64
#      2   21    15     48.5    0.717    20
# Total extinctions: 0
# Generation time: 0.325 sec (0.331 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 38.05778 stdev: 13.37596
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.691
# Mean genetic distance 1.204, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68    16     48.5    0.703    65
#      2   22    14     48.5    0.678    21
# Total extinctions: 0
# Generation time: 0.320 sec (0.330 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 35.72000 stdev: 15.21217
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.678
# Mean genetic distance 1.245, standard deviation 0.547
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    15     48.5    0.701    66
#      2   23    15     48.5    0.655    22
# Total extinctions: 0
# Generation time: 0.325 sec (0.328 average)
#
#  ****** Running generation 70 ******
# Population's average fitness: 35.92444 stdev: 14.78015
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.628
# Mean genetic distance 1.210, standard deviation 0.534
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70    13     48.5    0.451    67
#      2   24    17     48.5    0.804    23
# Total extinctions: 0
# Generation time: 0.327 sec (0.328 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 37.83556 stdev: 13.54777
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.704
# Mean genetic distance 1.221, standard deviation 0.584
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71    16     48.5    0.854    68
#      2   25    14     48.5    0.554    24
# Total extinctions: 0
# Generation time: 0.321 sec (0.327 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 38.95556 stdev: 15.01458
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.760
# Mean genetic distance 1.206, standard deviation 0.559
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72    15     48.5    0.774    69
#      2   26    15     48.5    0.745    25
# Total extinctions: 0
# Generation time: 0.330 sec (0.327 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 35.43111 stdev: 13.52388
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.613
# Mean genetic distance 1.200, standard deviation 0.573
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73    16     48.5    0.655    70
#      2   27    14     48.5    0.571    26
# Total extinctions: 0
# Generation time: 0.330 sec (0.326 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 36.64889 stdev: 15.45408
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.700
# Mean genetic distance 1.267, standard deviation 0.567
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   74    15     48.5    0.737    71
#      2   28    15     48.5    0.664    27
# Total extinctions: 0
# Generation time: 0.323 sec (0.325 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 37.70222 stdev: 13.10162
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.729
# Mean genetic distance 1.232, standard deviation 0.576
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   75    14     48.5    0.728    72
#      2   29    16     48.5    0.731    28
# Total extinctions: 0
# Generation time: 0.324 sec (0.326 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 36.88000 stdev: 14.45158
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.660
# Mean genetic distance 1.229, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   76    13     48.5    0.595    73
#      2   30    17     48.5    0.724    29
# Total extinctions: 0
# Generation time: 0.325 sec (0.325 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 34.82667 stdev: 14.79124
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.613
# Mean genetic distance 1.308, standard deviation 0.568
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   77    15     48.5    0.654    74
#      2   31    15     48.5    0.572    30
# Total extinctions: 0
# Generation time: 0.320 sec (0.325 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 40.19556 stdev: 12.70804
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.792
# Mean genetic distance 1.247, standard deviation 0.578
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   78    15     48.5    0.770    75
#      2   32    15     48.5    0.813    31
# Total extinctions: 0
# Generation time: 0.324 sec (0.325 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 39.07556 stdev: 13.64971
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.722
# Mean genetic distance 1.200, standard deviation 0.606
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   79    16     48.5    0.751    76
#      2   33    14     48.5    0.693    32
# Total extinctions: 0
# Generation time: 0.331 sec (0.326 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 35.95111 stdev: 14.95286
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.679
# Mean genetic distance 1.191, standard deviation 0.586
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   80    17     48.5    0.781    77
#      2   34    13     48.5    0.576    33
# Total extinctions: 0
# Generation time: 0.323 sec (0.325 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 38.65778 stdev: 13.72975
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.728
# Mean genetic distance 1.138, standard deviation 0.523
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   81    16     48.5    0.600    78
#      2   35    14     48.5    0.856    34
# Total extinctions: 0
# Generation time: 0.325 sec (0.326 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 37.34667 stdev: 13.94080
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.678
# Mean genetic distance 1.184, standard deviation 0.583
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   82    14     48.5    0.557    79
#      2   36    16     48.5    0.798    35
# Total extinctions: 0
# Generation time: 0.332 sec (0.326 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 38.72444 stdev: 13.04614
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.705
# Mean genetic distance 1.159, standard deviation 0.577
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   83    14     48.5    0.630    80
#      2   37    16     48.5    0.781    36
# Total extinctions: 0
# Generation time: 0.324 sec (0.325 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 40.57333 stdev: 12.86728
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.767
# Mean genetic distance 1.148, standard deviation 0.568
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   84    15     48.5    0.777    81
#      2   38    15     48.5    0.758    37
# Total extinctions: 0
# Generation time: 0.326 sec (0.325 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 36.90667 stdev: 14.31185
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.667
# Mean genetic distance 1.252, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   85    14     48.5    0.621    82
#      2   39    16     48.5    0.714    38
# Total extinctions: 0
# Generation time: 0.329 sec (0.326 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: 37.98667 stdev: 13.27527
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.689
# Mean genetic distance 1.248, standard deviation 0.562
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   86    14     48.5    0.586    83
#      2   40    16     48.5    0.792    39
# Total extinctions: 0
# Generation time: 0.327 sec (0.326 average)
#
#  ****** Running generation 87 ******
# Population's average fitness: 37.22222 stdev: 14.37834
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.715
# Mean genetic distance 1.201, standard deviation 0.566
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   87    15     48.5    0.689    84
#      2   41    15     48.5    0.742    40
# Total extinctions: 0
# Generation time: 0.333 sec (0.327 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 35.75556 stdev: 13.94602
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.631
# Mean genetic distance 1.248, standard deviation 0.570
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   88    17     48.5    0.797    85
#      2   42    13     48.5    0.465    41
# Total extinctions: 0
# Generation time: 0.333 sec (0.328 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 35.53778 stdev: 13.85366
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.649
# Mean genetic distance 1.216, standard deviation 0.587
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   89    15     48.5    0.595    86
#      2   43    15     48.5    0.702    42
# Total extinctions: 0
# Generation time: 0.331 sec (0.328 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 40.03556 stdev: 13.81850
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.755
# Mean genetic distance 1.163, standard deviation 0.612
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   90    16     48.5    0.821    87
#      2   44    14     48.5    0.688    43
# Total extinctions: 0
# Generation time: 0.330 sec (0.329 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 39.45778 stdev: 13.57584
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.735
# Mean genetic distance 1.240, standard deviation 0.585
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   91    15     48.5    0.716    88
#      2   45    15     48.5    0.755    44
# Total extinctions: 0
# Generation time: 0.336 sec (0.330 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 35.46667 stdev: 14.49377
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.623
# Mean genetic distance 1.198, standard deviation 0.618
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   92    14     48.5    0.613    89
#      2   46    16     48.5    0.633    45
# Total extinctions: 0
# Generation time: 0.328 sec (0.330 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 39.45333 stdev: 13.10843
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.732
# Mean genetic distance 1.236, standard deviation 0.558
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   93    15     48.5    0.698    90
#      2   47    15     48.5    0.766    46
# Total extinctions: 0
# Generation time: 0.336 sec (0.331 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 37.52444 stdev: 14.10209
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.725
# Mean genetic distance 1.246, standard deviation 0.583
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   94    16     48.5    0.763    91
#      2   48    14     48.5    0.687    47
# Total extinctions: 0
# Generation time: 0.336 sec (0.332 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 38.83111 stdev: 13.38814
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.759
# Mean genetic distance 1.249, standard deviation 0.633
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   95    15     48.5    0.732    92
#      2   49    15     48.5    0.786    48
# Total extinctions: 0
# Generation time: 0.333 sec (0.332 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 34.84000 stdev: 13.48888
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.608
# Mean genetic distance 1.250, standard deviation 0.620
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   96    16     48.5    0.665    93
#      2   50    14     48.5    0.551    49
# Total extinctions: 0
# Generation time: 0.332 sec (0.333 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 40.64000 stdev: 12.57239
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.797
# Mean genetic distance 1.272, standard deviation 0.609
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   97    17     48.5    0.878    94
#      2   51    13     48.5    0.716    50
# Total extinctions: 0
# Generation time: 0.333 sec (0.333 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 39.02222 stdev: 13.10133
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.681
# Mean genetic distance 1.239, standard deviation 0.576
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   98    16     48.5    0.662    95
#      2   52    14     48.5    0.700    51
# Total extinctions: 0
# Generation time: 0.343 sec (0.334 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 34.00444 stdev: 14.11216
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.633
# Mean genetic distance 1.295, standard deviation 0.607
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   99    17     48.5    0.691    96
#      2   53    13     48.5    0.574    52
# Total extinctions: 0
# Generation time: 0.336 sec (0.334 average)
#
#  ****** Running generation 100 ******
#
# Population's average fitness: 39.29333 stdev: 13.84067
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.780
# Mean genetic distance 1.261, standard deviation 0.581
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  100    15     48.5    0.698    97
#      2   54    15     48.5    0.861    53
# Total extinctions: 0
# Generation time: 0.344 sec (0.336 average)
#
#  ****** Running generation 101 ******
#
# Population's average fitness: 35.12444 stdev: 14.33941
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.613
# Mean genetic distance 1.239, standard deviation 0.600
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  101    14     48.5    0.598    98
#      2   55    16     48.5    0.628    54
# Total extinctions: 0
# Generation time: 0.327 sec (0.335 average)
#
#  ****** Running generation 102 ******
#
# Population's average fitness: 34.81778 stdev: 15.13921
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.659
# Mean genetic distance 1.299, standard deviation 0.586
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  102    15     48.5    0.695    99
#      2   56    15     48.5    0.624    55
# Total extinctions: 0
# Generation time: 0.329 sec (0.335 average)
#
#  ****** Running generation 103 ******
# Population's average fitness: 34.40000 stdev: 16.08787
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.647
# Mean genetic distance 1.263, standard deviation 0.596
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  103    14     48.5    0.525   100
#      2   57    16     48.5    0.769    56
# Total extinctions: 0
# Generation time: 0.326 sec (0.334 average)
#
#  ****** Running generation 104 ******
#
# Population's average fitness: 38.90667 stdev: 14.39677
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.715
# Mean genetic distance 1.279, standard deviation 0.593
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  104    14     48.5    0.665   101
#      2   58    16     48.5    0.765    57
# Total extinctions: 0
# Generation time: 0.332 sec (0.333 average)
#
#  ****** Running generation 105 ******
#
# Population's average fitness: 40.69333 stdev: 12.76497
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.800
# Mean genetic distance 1.230, standard deviation 0.580
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  105    13     48.5    0.739   102
#      2   59    17     48.5    0.861    58
# Total extinctions: 0
# Generation time: 0.334 sec (0.334 average)
#
#  ****** Running generation 106 ******
#
# Population's average fitness: 36.71111 stdev: 13.20630
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.648
# Mean genetic distance 1.261, standard deviation 0.584
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  106    15     48.5    0.603   103
#      2   60    15     48.5    0.692    59
# Total extinctions: 0
# Generation time: 0.326 sec (0.333 average)
#
#  ****** Running generation 107 ******
#
# Population's average fitness: 34.72889 stdev: 14.48186
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.602
# Mean genetic distance 1.286, standard deviation 0.594
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  107    14     48.5    0.533   104
#      2   61    16     48.5    0.671    60
# Total extinctions: 0
# Generation time: 0.348 sec (0.334 average)
#
#  ****** Running generation 108 ******
#
# Population's average fitness: 36.25333 stdev: 13.73546
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.643
# Mean genetic distance 1.207, standard deviation 0.601
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  108    15     48.5    0.607   105
#      2   62    15     48.5    0.679    61
# Total extinctions: 0
# Generation time: 0.337 sec (0.334 average)
#
#  ****** Running generation 109 ******
#
# Population's average fitness: 36.75556 stdev: 14.90992
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.706
# Mean genetic distance 1.304, standard deviation 0.604
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  109    16     48.5    0.755   106
#      2   63    14     48.5    0.656    62
# Total extinctions: 0
# Generation time: 0.331 sec (0.333 average)
#
#  ****** Running generation 110 ******
#
# Population's average fitness: 37.51111 stdev: 14.16831
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.692
# Mean genetic distance 1.236, standard deviation 0.617
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  110    14     48.5    0.573   107
#      2   64    16     48.5    0.812    63
# Total extinctions: 0
# Generation time: 0.338 sec (0.333 average)
#
#  ****** Running generation 111 ******
#
# Population's average fitness: 40.44889 stdev: 13.14496
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.780
# Mean genetic distance 1.309, standard deviation 0.622
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  111    16     48.5    0.898   108
#      2   65    14     48.5    0.661    64
# Total extinctions: 0
# Generation time: 0.327 sec (0.333 average)
#
#  ****** Running generation 112 ******
#
# Population's average fitness: 34.82667 stdev: 14.88466
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.665
# Mean genetic distance 1.317, standard deviation 0.588
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  112    14     48.5    0.550   109
#      2   66    16     48.5    0.780    65
# Total extinctions: 0
# Generation time: 0.332 sec (0.333 average)
#
#  ****** Running generation 113 ******
#
# Population's average fitness: 36.56889 stdev: 14.62973
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.706
# Mean genetic distance 1.343, standard deviation 0.576
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  113    15     48.5    0.783   110
#      2   67    15     48.5    0.629    66
# Total extinctions: 0
# Generation time: 0.339 sec (0.334 average)
#
#  ****** Running generation 114 ******
#
# Population's average fitness: 37.67111 stdev: 13.76156
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.728
# Mean genetic distance 1.255, standard deviation 0.575
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  114    14     48.5    0.710   111
#      2   68    16     48.5    0.747    67
# Total extinctions: 0
# Generation time: 0.391 sec (0.340 average)
#
#  ****** Running generation 115 ******
#
# Population's average fitness: 38.54667 stdev: 12.63037
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.718
# Mean genetic distance 1.348, standard deviation 0.594
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  115    17     48.5    0.784   112
#      2   69    13     48.5    0.653    68
# Total extinctions: 0
# Generation time: 0.333 sec (0.340 average)
#
#  ****** Running generation 116 ******
#
# Population's average fitness: 30.85778 stdev: 14.28450
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.488
# Mean genetic distance 1.286, standard deviation 0.577
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  116    16     48.5    0.535   113
#      2   70    14     48.5    0.440    69
# Total extinctions: 0
# Generation time: 0.319 sec (0.340 average)
#
#  ****** Running generation 117 ******
#
# Population's average fitness: 34.45778 stdev: 14.94736
# Best fitness: 48.53333 - size: (4, 15) - species 1 - id 185
# Average adjusted fitness: 0.597
# Mean genetic distance 1.265, standard deviation 0.572
# Population of 30 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1  117    14     48.5    0.450   114
#      2   71    16     48.5    0.744    70
# Total extinctions: 0
# Generation time: 0.322 sec (0.337 average)
#
#  ****** Running generation 118 ******
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Lucas\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
